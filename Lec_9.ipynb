# %% [markdown]
# <a href="https://colab.research.google.com/github/mayooreshmoodanwal/Data-Science/blob/main/Lec_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#####OOPS#####

# %%
class mirai_class:
  strength = 100
  teacher = ['A','B','C']
  div = ['alpha','beta']
  sub = ['ds','dev','dsa']

  def __init__(self):
    print('I am Inevitable')

obj = mirai_class()

print(obj.strength)
# Out:
# I am Inevitable
# 100

# %%
class student:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def display(self):
    print(self.name,self.age)

a = student('Udit',20)

a.display()

print(a.name)
print(a.age)
# Out:
# Udit 20
# Udit
# 20
